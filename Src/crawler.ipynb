# %% [markdown]
# # Web Scraping: The Guardian¶
# * [Ref Github Link](https://github.com/miguelfzafra/Latest-News-Classifier)

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time

# %% [markdown]
# ## Obtain list of news from the coverpage¶
# URL definition:

# %%
# url definition
url = "https://www.theguardian.com/uk"

# %% [markdown]
# List of news:

# %%
# Request
r1 = requests.get(url)
r1.status_code

# We'll save in coverpage the cover page content
coverpage = r1.content

# Soup creation
soup1 = BeautifulSoup(coverpage, 'html5lib')

# News identification
coverpage_news = soup1.find_all('h3', class_='fc-item__title')
len(coverpage_news)
# Out:
# 125

# %% [markdown]
# ## Let's extract the text from the articles:¶
# First, we'll define the number of articles we want:

# %%
number_of_articles = 125

# %%
# Empty lists for content, links and titles
news_contents = []
list_links = []
list_titles = []

for n in np.arange(0, number_of_articles):
        
        # We need to ignore "live" pages since they are not articles
        if "live" in coverpage_news[n].find('a')['href']:  
                continue

        # Getting the link of the article
        link = coverpage_news[n].find('a')['href']
        list_links.append(link)

        # Getting the title
        title = coverpage_news[n].find('a').get_text()
        list_titles.append(title)

        # Reading the content (it is divided in paragraphs)
        article = requests.get(link)
        article_content = article.content
        soup_article = BeautifulSoup(article_content, 'html5lib')
        #print(soup_article)
        body = soup_article.find_all('p', class_='dcr-s23rjr')

        # Unifying the paragraphs
        list_paragraphs = []
        for p in body:
                paragraph = p.get_text()
                list_paragraphs.append(paragraph)
                final_article = " ".join(list_paragraphs)

        news_contents.append(final_article)

# %% [markdown]
# ## Let's put them into:
#
# * a dataset which will the input of the models (df_features)

# %%
news_contents[6]
# Out:
# 'The Conservative MP Sir David Amess died on Friday after being stabbed multiple times at a constituency surgery. Here is what we know so far:'

# %%
# df_features
df_features = pd.DataFrame(
     {'Article Content': news_contents 
})

# %%
for news in news_contents:
    print(news)
# Out:
# The Speaker of the House of Commons, Sir Lindsay Hoyle, has demanded “an end to hatred” against MPs and a kinder form of political discourse following the fatal stabbing of Sir David Amess, as evidence mounts of the shocking scale of intimidation and threats suffered daily by elected politicians and their staff. In a highly unusual intervention for a Commons Speaker, Hoyle makes the appeal as he writes in the Observer. He describes the late Tory MP and father of five as a friend who would regularly drop into his office for a chat, and as “a man who found a connection with everyone, no matter their background”. On Saturday, political leaders put on a defiant show of unity and solidarity, with Boris Johnson and Sir Keir Starmer, along with Hoyle and the home secretary, Priti Patel, together laying wreaths at Belfairs Methodist church in Leigh-on-Sea, Essex, where Amess died after being stabbed repeatedly as he held his constituency surgery on Friday. A man was arrested shortly after the attack and remains in police custody. The suspect, named by police sources as Ali Harbi Ali, 25, is said to be a British national of Somali heritage, who is believed to have been referred to the Prevent programme but is not on MI5’s database of persons of interest. Detectives were on Saturday granted a warrant to hold him until 22 October. Hoyle, who reveals how he decided to hold his own two-hour surgery just four hours after learning of Amess’s killing, says that while the security offered to MPs must now be reviewed, there is a wider problem about the levels of hatred and intimidation in politics that must be addressed. “If anything positive is to come out of this latest awful tragedy,” he says, “it is that the quality of political discourse has to
information – the same information on which we base many of the most important decisions of our lives – is fundamental to our survival …The only accurate way to describe the government’s response to our report is ‘lamentable’,” Puttnam said. A resident of West Cork in Ireland for more than 20 years, Puttnam also pointed to the “pig-ignorance” displayed by MPs during Brexit negotiations towards the Irish border as another reason for his departure from politics, and said he was “embarrassed” by the country Britain had become since leaving the EU. “Mirroring the anxieties of many of those angry Brexiteers in 2016, I feel I’ve had my country of birth, and the values I believed it to represent, stolen from me … I find myself embarrassed by what, on an almost daily basis, I see it becoming – my old enemy Rupert Murdoch’s dream made real. He never liked Britain, and he’s kind of won, he’s helped remake it in his own malevolent image,” he said.

# %%
all_content = []
for news in news_contents:
        tmp_content = news.replace('“', '').replace('”','').replace('’','').split(". ")
        
        for tmp in tmp_content:
                for tmp2 in tmp.split(", "):
                        all_content.append(tmp2)

# %%
final_content = []
statistic = []
for unique_content in np.unique(all_content):
    if len(unique_content.strip()) >= 500:
        final_content.append(unique_content.strip()[:499])
    else:
        final_content.append(unique_content.strip())
    statistic.append(len(unique_content.strip()))

# %% [markdown]
# # DB Manipulation
# * https://datatofish.com/how-to-connect-python-to-sql-server-using-pyodbc/

# %% [markdown]
# # Connect to DB

# %%
import pyodbc 

# SELECT @@SERVERNAME
# Use this to find servername

conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=LAPTOP-Q0DB1ITI\SQLEXPRESS;'
                      'Database=DB;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM ATData')

for i in cursor:
    print(i)
# Out:
# (1, 'Hi, my name is Eric.', 'C:default/path/to/your/audio/file')
# (2, '', 'C:default/path/to/your/audio/file')
# (3, 'According to West', 'C:default/path/to/your/audio/file')
# (4, 'All the snakes were northern Pacific rattlesnakes', 'C:default/path/to/your/audio/file')
# (5, 'CNN first reported in February 2021 that court documents showed that the two private jets used by the Saudi assassination squad were owned by a company that had previously been seized by Prince Mohammed', 'C:default/path/to/your/audio/file')
# (6, 'Edwards is now considering suing Santander for indirect discrimination', 'C:default/path/to/your/audio/file')
# (7, 'Floella Benjamin', 'C:default/path/to/your/audio/file')
# (8, 'For his part', 'C:default/path/to/your/audio/file')
# (9, 'He feels he and his commission colleagues did their best', 'C:default/path/to/your/audio/file')
# (10, 'He spent 12 years teaching in London', 'C:default/path/to/your/audio/file')
# (11, 'I kept finding snakes for the next almost four hours', 'C:default/path/to/your/audio/file')
# (12, 'In 2019', 'C:default/path/to/your/audio/file')
# (13, 'Instead of overtly embracing Trump', 'C:default/path/to/your/audio/file')
# (14, 'Nearby residents and a rescue team managed to save 10 of the students', 'C:default/path/to/your/audio/file')
# (15, 'On Friday the prime minister', 'C:default/path/to/your/audio/file')
# (16, 'On Thursday', 'C:default/path/to/your/audio/file')
# (17, 'Outside China', 'C:default/path/to/your/audio/file')
# (18, 'People use #WhatIEatInADay to brag about their diet', 'C:default/path/to/your/audio/file')
# (19, 'Power companies are moving away from coal as generation assets age', 'C:default/path/to/your/audio/file')
# (20, 'Preliminary results from a carbon life cycle analysis indicate that the companys coffee produces a tenth of the greenhouse gas emissions and water use of traditional coffee', 'C:default/path/to/your/audio/file')
# (21, 'Servini wrote that Martin Villa had played a key role in the repressive structures of the dictatorship', 'C:default/path/to/your/audio/file')
# (22, 'The Intergovernmental Panel on Climate Change drops its latest report', 'C:default/path/to/your/audio/file')
# (23, 'The key policy he has fought for is better funding for pupils aged 16 to 19 in education: he thinks the pupil premium should be extended for disadvantaged students in this age group', 'C:default/path/to/your/audio/file')
# (24, 'The move north gave him what he calls his political edge', 'C:default/path/to/your/audio/file')
# (25, 'The proposal has come under criticism from some who believe it is not enough and yet more targets will only drive people out of the profession', 'C:default/path/to/your/audio/file')
# (26, 'The single biggest issue preoccupying her is the trusts role', 'C:default/path/to/your/audio/file')
# (27, 'This is is a dramatic scene from Fit', 'C:default/path/to/your/audio/file')
# (28, 'While high street banks may seem more risk-averse', 'C:default/path/to/your/audio/file')
# (29, 'Wright', 'C:default/path/to/your/audio/file')
# (30, '#WhatIEatInADay', 'C:default/path/to/your/audio/file')
# (31, '(Museum-style labelling is a surprisingly big bone of contention among members nostalgic for the days when the rooms of country houses were assumed to speak for themselves.) This rather esoteric crusade against dumbing down has', 'C:default/path/to/your/audio/file')
# (32, '(Not the coal ones though.) The investment is a bit of a turnaround from 2015 when Abbott tried to abolish the fund', 'C:default/path/to/your/audio/file')
# (33, '(The Spectators editor', 'C:default/path/to/your/audio/file')
# (34, '(The trust insists Parkers departure was planned', 'C:default/path/to/your/audio/file')
# (35, '(The trust occupies an unusual position', 'C:default/path/to/your/audio/file')
# (36, '10', 'C:default/path/to/your/audio/file')
# (37, '10 detectives will be investigating as many as 800 cases', 'C:default/path/to/your/audio/file')
# (38, '15', 'C:default/path/to/your/audio/file')
# (39, '18', 'C:default/path/to/your/audio/file')
# (40, '2008', 'C:default/path/to/your/audio/file')
# (41, '20? Lets put it in place', 'C:default/path/to/your/audio/file')
# (42, '24,000 illegal constructions have been built', 'C:default/path/to/your/audio/file')
# (43, '25', 'C:default/path/to/your/audio/file')
# (44, '30-year-old escort Charlotte Edwards made headlines when she started a campaign to guarantee sex workers fair access to banking', 'C:default/path/to/your/audio/file')
# (45, '32', 'C:default/path/to/your/audio/file')
# (46, '51', 'C:default/path/to/your/audio/file')
# (47, '60% of whom are between the ages of 16 and 24', 'C:default/path/to/your/audio/file')
# (48, '71 and 65 in the past three days', 'C:default/path/to/your/audio/file')
# (49, '74', 'C:default/path/to/your/audio/file')
# (50, '76', 'C:default/path/to/your/audio/file')
# (51, '78', 'C:default/path/to/your/audio/file')
# (52, '86', 'C:default/path/to/your/audio/file')
# (53, '87', 'C:default/path/to/your/audio/file')
# (54, '95.5% of people in the highest risk age group', 'C:default/path/to/your/audio/file')
# (55, 'A 13-year-old girl has died after being struck by a car in Dover', 'C:default/path/to/your/audio/file')
# (56, 'A 16-year-old boy has been charged with murder over the fatal stabbing of a teenager on a playing field', 'C:default/path/to/your/audio/file')
# (57, 'A 2019 survey by Dalhousie University found that 72% of Canadians say they would not drink lab-grown coffee', 'C:default/path/to/your/audio/file')
# (58, 'A Nasa spacecraft named Lucy has rocketed into the sky with diamonds on a 12-year quest to explore eight asteroids', 'C:default/path/to/your/audio/file')
# (59, 'A blackboard at the entrance advertises traditional games every Thursday', 'C:default/path/to/your/audio/file')
# (60, 'A ceiling collapsed and he lost his lower left leg', 'C:default/path/to/your/audio/file')
# (61, 'A clique of powerful', 'C:default/path/to/your/audio/file')
# (62, 'A default market offer for energy prices is also introduced', 'C:default/path/to/your/audio/file')
# (63, 'A few days later', 'C:default/path/to/your/audio/file')
# (64, 'A former naval surgeon whose Wiltshire constituency includes Stourhead – named in the colonialism and slavery report because its 18th-century owner inherited money made partly from trading shares in the South Sea company', 'C:default/path/to/your/audio/file')
# (65, 'A group called Restore Trust – a rebel alliance of disgruntled members seeking to oust senior National Trust leaders – has now tabled a series of resolutions for the charitys annual general meeting later this month', 'C:default/path/to/your/audio/file')
# (66, 'A group of rampant hippopotamuses', 'C:default/path/to/your/audio/file')
# (67, 'A hospital spokesperson said the patient was moved into A&E but sadly died in the department', 'C:default/path/to/your/audio/file')
# (68, 'A key issue is the way that international law draws the difference between an island and just a rock', 'C:default/path/to/your/audio/file')
# (69, 'A lot has changed since that day', 'C:default/path/to/your/audio/file')
# (70, 'A lot of people have bought into that', 'C:default/path/to/your/audio/file')
# (71, 'A lot of people here', 'C:default/path/to/your/audio/file')
# (72, 'A man has been charged with sexual offences after allegedly kidnapping a teenage girl while impersonating a police officer', 'C:default/path/to/your/audio/file')
# (73, 'A man was arrested shortly after the attack and remains in police custody', 'C:default/path/to/your/audio/file')
# (74, 'A member for 40 years', 'C:default/path/to/your/audio/file')
# (75, 'A new government and NHS action plan will see GPs given ￡250m to improve their services but only if they increase the number of patients being seen face-to-face', 'C:default/path/to/your/audio/file')
# (76, 'A parliamentary inquiry is established to look into an Australian nuclear power industry', 'C:default/path/to/your/audio/file')
# (77, 'A part of me is always at war', 'C:default/path/to/your/audio/file')
# (78, 'A patient died last Monday after suffering a suspected heart attack in the back of an ambulance which had been queueing for more than two hours outside James Paget University Hospital at Gorleston-on-Sea in Norfolk', 'C:default/path/to/your/audio/file')
# (79, 'A possible trigger for such a reappraisal may be the continued strain on the NHS', 'C:default/path/to/your/audio/file')
# (80, 'A powerful way of normalising a situation is to explain it through natural phenomenon', 'C:default/path/to/your/audio/file')
# (81, 'A recent book on the Biden family by the Politico journalist Ben Schreckinger presents evidence that some emails allegedly leaked from Hunters laptop regarding business deals were genuine and not', 'C:default/path/to/your/audio/file')
# (82, 'A resident of West Cork in Ireland for more than 20 years', 'C:default/path/to/your/audio/file')
# (83, 'A series of commissioned murals in Cardiff city centre was mistakenly washed away by cleaning staff after a devastating miscommunication', 'C:default/path/to/your/audio/file')
# (84, 'A series of corruption scandals in the city brought down several high profile officials shortly after President Xi Jinping came to power in 2013; there are concerns over the high number of babies born with congenital defects', 'C:default/path/to/your/audio/file')
# (85, 'A smile that seems to hide his anger; a smile that reminds me of the final line of Gomorrah: Damned bastards', 'C:default/path/to/your/audio/file')
# (86, 'A soldier has died during an army training exercise at a military facility in Wiltshire', 'C:default/path/to/your/audio/file')
# (87, 'A source at the Department for Business', 'C:default/path/to/your/audio/file')
# (88, 'A spokesperson emails that its chief concern is a shift of power from expert curators to managers charged with boosting visitor numbers', 'C:default/path/to/your/audio/file')
# (89, 'A spokesperson for the Department for Levelling Up', 'C:default/path/to/your/audio/file')
# (90, 'A spokesperson for the Saudi embassy in Washington did not return a request for comment', 'C:default/path/to/your/audio/file')
# (91, 'A spokeswoman for TikTok said the platform works to balance censorship of problematic content with efforts to encourage content that is related to prevention of eating disorders', 'C:default/path/to/your/audio/file')
# (92, 'A standoff with private power companies heats up over the future of their ageing coal assets', 'C:default/path/to/your/audio/file')
# (93, 'A statement from Blue Origin said the company had dismissed Abrams for repeated warnings for issues involving federal export control regulations', 'C:default/path/to/your/audio/file')
# (94, 'A top Republican politician in North Carolina is facing a wave of outrage and backlash', 'C:default/path/to/your/audio/file')
# (95, 'A transportation spokesperson said Buttigieg has been ramping up activities and is expected to continue to take some time over the coming weeks to support his husband and take care of his new children', 'C:default/path/to/your/audio/file')
# (96, 'A warrant of further detention', 'C:default/path/to/your/audio/file')
# (97, 'A week later Prince Mohammed called back and told Rumayyan he was starting immediately', 'C:default/path/to/your/audio/file')
# (98, 'A year ago', 'C:default/path/to/your/audio/file')
# (99, 'A year on', 'C:default/path/to/your/audio/file')
# (100, 'Abdelnaby Abdelelah', 'C:default/path/to/your/audio/file')
# (101, 'About 10 Hindu temples and shrines were attacked and vandalised by the crowds', 'C:default/path/to/your/audio/file')
# (102, 'About two hours later she said officers came to her home', 'C:default/path/to/your/audio/file')
# (103, 'Abrams described a company where executives show consistently inappropriate behavior toward women and where dissent is actively stifled', 'C:default/path/to/your/audio/file')
# (104, 'Abrams partially attributes the mounting technical debt to Blue Origins increasing focus on speed', 'C:default/path/to/your/audio/file')
# (105, 'Abrams said', 'C:default/path/to/your/audio/file')
# (106, 'Abrams said the company suffers from an immense amount of technical debt–engineering challenges that build up as a result of choosing a quick solution rather than the best solution – and a relentless focus on speed that undermined its ability to properly address problems with its launch vehicles', 'C:default/path/to/your/audio/file')
# (107, 'Abrams whistleblower essay was co-signed by 20 anonymous current and former Blue Origin employees', 'C:default/path/to/your/audio/file')
# (108, 'Accompanied by the rumble of helicopters', 'C:default/path/to/your/audio/file')
# (109, 'According to Abrams', 'C:default/path/to/your/audio/file')
# (110, 'According to Peter Montgomery', 'C:default/path/to/your/audio/file')
# (111, 'According to Reicher', 'C:default/path/to/your/audio/file')
# (112, 'According to Sussex police', 'C:default/path/to/your/audio/file')
# (113, 'According to an update this week', 'C:default/path/to/your/audio/file')
# (114, 'According to multiple sources the man is said not to be on MI5s vast', 'C:default/path/to/your/audio/file')
# (115, 'According to the Ministry of Health', 'C:default/path/to/your/audio/file')
# (116, 'According to witnesses', 'C:default/path/to/your/audio/file')
# (117, 'Across Shanxi', 'C:default/path/to/your/audio/file')
# (118, 'Across the road', 'C:default/path/to/your/audio/file')
# (119, 'Actually what I want is to get more people back into the houses to really learn a bit more', 'C:default/path/to/your/audio/file')
# (120, 'After Escobars death', 'C:default/path/to/your/audio/file')
# (121, 'After Gomorrah was published', 'C:default/path/to/your/audio/file')
# (122, 'After Rumayyan initially said he could start the job in three months', 'C:default/path/to/your/audio/file')
# (123, 'After Tony Abbott repealed Labors carbon price', 'C:default/path/to/your/audio/file')
# (124, 'After a fiery launch', 'C:default/path/to/your/audio/file')
# (125, 'After all', 'C:default/path/to/your/audio/file')
# (126, 'After first saying his job was to stay and speak to Australians about the plan', 'C:default/path/to/your/audio/file')
# (127, 'After her release earlier this year', 'C:default/path/to/your/audio/file')
# (128, 'After spending several months in a recovery center', 'C:default/path/to/your/audio/file')
# (129, 'After the 2016 shooting at Pulse', 'C:default/path/to/your/audio/file')
# (130, 'After the first world war', 'C:default/path/to/your/audio/file')
# (131, 'After the video went viral on Facebook earlier this week', 'C:default/path/to/your/audio/file')
# (132, 'Again', 'C:default/path/to/your/audio/file')
# (133, 'Against the Odds', 'C:default/path/to/your/audio/file')
# (134, 'Air New Zealand opened one of its Boeing 787s to allow a lucky few to be vaccinated in business class', 'C:default/path/to/your/audio/file')
# (135, 'Al Wolf is used to clearing one or two snakes from under houses but recently was called by a woman who said she had seen rattlesnakes scurry under her northern California house and was surprised to find more than 90 rattlesnakes getting ready to hibernate', 'C:default/path/to/your/audio/file')
# (136, 'Alan Finkel', 'C:default/path/to/your/audio/file')
# (137, 'Albanian police issued a statement on Saturday saying the tourists were found asphyxiated in a hotel sauna in the village of Qerret late on Friday', 'C:default/path/to/your/audio/file')
# (138, 'Ali is said to have lived or have family links in the Southend area but had moved to London', 'C:default/path/to/your/audio/file')
# (139, 'Alisson Scott', 'C:default/path/to/your/audio/file')
# (140, 'All but one of the new cases were in Auckland', 'C:default/path/to/your/audio/file')
# (141, 'All of this is geared towards the coming 2019 election', 'C:default/path/to/your/audio/file')
# (142, 'All preliminary investigative leads were exhausted and there were no signs of foul play', 'C:default/path/to/your/audio/file')
# (143, 'All these options come with a cost', 'C:default/path/to/your/audio/file')
# (144, 'All three strands of opposition are converging on the AGM', 'C:default/path/to/your/audio/file')
# (145, 'Alongside Hill', 'C:default/path/to/your/audio/file')
# (146, 'Already there and more to come', 'C:default/path/to/your/audio/file')
# (147, 'Alternative coffee companies like Atomo not only have the potential to help tackle the climate crisis but to benefit the industry generally', 'C:default/path/to/your/audio/file')
# (148, 'Although Petitos and Charging Crows cases are very much distinct', 'C:default/path/to/your/audio/file')
# (149, 'Amber Forde and Temeka Davies who took the opportunity to brighten up Cardiff and contribute to its vibrant and exciting culture through their artworks … Were working with the creative director of the project as to how we can best rectify this situation as quickly as possible.', 'C:default/path/to/your/audio/file')
# (150, 'America is historically the worlds largest producer of greenhouse gasses and the US clean energy project was set to be the cornerstone of American efforts at Glasgow to push other countries to move faster on tackling climate change', 'C:default/path/to/your/audio/file')
# (151, 'American startups are also working on beanless coffee', 'C:default/path/to/your/audio/file')
# (152, 'Among the 20 companies included on a list to be transferred to the PIF was Sky Prime Aviation Services', 'C:default/path/to/your/audio/file')
# (153, 'An Argentinian judge investigating cases that happened during the Franco dictatorship in Spain has indicted a former Spanish minister on four counts of homicide', 'C:default/path/to/your/audio/file')
# (154, 'An Atlas V rocket blasted off before dawn on Saturday', 'C:default/path/to/your/audio/file')
# (155, 'An NHS spokesperson said: Ambulances responded to a record 76,000 life-threatening call-outs in Septemberan increase of more than 20,000 on the previous high for this month', 'C:default/path/to/your/audio/file')
# (156, 'An actual plan is now apparently forthcoming but first it has to get past the Nationals', 'C:default/path/to/your/audio/file')
# (157, 'An hour into our journey', 'C:default/path/to/your/audio/file')
# (158, 'An independent expert panel of experts who advise the Food and Drug Administration (FDA) is scheduled to debate the the safety and efficacy of the vaccines at a meeting in late October', 'C:default/path/to/your/audio/file')
# (159, 'An institution best known for stately homes', 'C:default/path/to/your/audio/file')
# (160, 'And Garcetti', 'C:default/path/to/your/audio/file')
# (161, 'And for the first time I think were being recognized for what we actually are', 'C:default/path/to/your/audio/file')
# (162, 'And going through this with the police department and people not helping you and not caring about you or not worrying about that', 'C:default/path/to/your/audio/file')
# (163, 'And here we have an obvious problem', 'C:default/path/to/your/audio/file')
# (164, 'And how would the authorities deal with the generations of coal miners and their families whove helped power China but who have no other skills in the new economy?', 'C:default/path/to/your/audio/file')
# (165, 'And it is bullshit', 'C:default/path/to/your/audio/file')
# (166, 'And just below the painting stands a bouquet of white chrysanthemums', 'C:default/path/to/your/audio/file')
# (167, 'And obviously', 'C:default/path/to/your/audio/file')
# (168, 'And on 29 September Shanxi promised to supply coal to 14 other regions across China to ensure sufficient energy throughout this winter', 'C:default/path/to/your/audio/file')
# (169, 'And psychologists say this steady stream of daily deaths – although the UK is now on an upwards trajectory – tends to feel less alarming than the rises we witnessed in the first year of the pandemic', 'C:default/path/to/your/audio/file')
# (170, 'And so', 'C:default/path/to/your/audio/file')
# (171, 'And soon', 'C:default/path/to/your/audio/file')
# (172, 'And thats even with a carbon price', 'C:default/path/to/your/audio/file')
# (173, 'And the headwinds are strong – she will need to push hard to get concrete funding or policy decisions', 'C:default/path/to/your/audio/file')
# (174, 'And the president remains proud of his son', 'C:default/path/to/your/audio/file')
# (175, 'And then theres Blue Origin', 'C:default/path/to/your/audio/file')
# (176, 'And then they were reading this stuff', 'C:default/path/to/your/audio/file')
# (177, 'And there are those who argue that Saviano does not need an escort; that', 'C:default/path/to/your/audio/file')
# (178, 'And unlike Musk', 'C:default/path/to/your/audio/file')
# (179, 'And why would they be concerned', 'C:default/path/to/your/audio/file')
# (180, 'And yet', 'C:default/path/to/your/audio/file')
# (181, 'Andrew Bates', 'C:default/path/to/your/audio/file')
# (182, 'Angus Taylor', 'C:default/path/to/your/audio/file')
# (183, 'Another legal concern for the Marshall Islands brought on by sea level rise is that of losing its vast exclusive maritime zone and therefore access to crucial fisheries that provide much of the countrys food and contributes significantly to its GDP', 'C:default/path/to/your/audio/file')
# (184, 'Anyway', 'C:default/path/to/your/audio/file')
# (185, 'Apparently', 'C:default/path/to/your/audio/file')
# (186, 'Ardern broke the news at 3pm', 'C:default/path/to/your/audio/file')
# (187, 'Arderns fiance', 'C:default/path/to/your/audio/file')
# (188, 'Are private sector companies the best arbiters of morality? Their judgments are always going to be based ultimately on profit', 'C:default/path/to/your/audio/file')
# (189, 'Are there mountains? Valleys? Pits? Mesas? Who knows? Im sure were going to be surprised', 'C:default/path/to/your/audio/file')
# (190, 'Are you a GP? What do you think of the proposals? Do you think this extra money linked to face-to-face appointments will help both patients and GPs? As a GP how do you think services could be improved? You can get in touch by filling in the form below or contact us via WhatsApp by clicking here or adding +44(0)7766780300', 'C:default/path/to/your/audio/file')
# (191, 'Arindam Bagchi', 'C:default/path/to/your/audio/file')
# (192, 'Around noon', 'C:default/path/to/your/audio/file')
# (193, 'Artessa Saldivar-Sali', 'C:default/path/to/your/audio/file')
# (194, 'As Eleanor Harding', 'C:default/path/to/your/audio/file')
# (195, 'As Johnson prepares to position the UK at the head of global efforts to combat climate change and curb greenhouse gas emissions as host of the Glasgow Cop26 meeting', 'C:default/path/to/your/audio/file')
# (196, 'As a Native woman', 'C:default/path/to/your/audio/file')
# (197, 'As a child', 'C:default/path/to/your/audio/file')
# (198, 'As a disease shifts from an initial pandemic phase to an endemic illness', 'C:default/path/to/your/audio/file')
# (199, 'As always', 'C:default/path/to/your/audio/file')
# (200, 'As an activist', 'C:default/path/to/your/audio/file')
# (201, 'As if it were my decision', 'C:default/path/to/your/audio/file')
# (202, 'As of 7pm local time (0700 BST)', 'C:default/path/to/your/audio/file')
# (203, 'As our journey draws to a close at the foot of Vesuvius', 'C:default/path/to/your/audio/file')
# (204, 'As the police investigation continued into the night and the pile of flowers outside the church steadily grew', 'C:default/path/to/your/audio/file')
# (205, 'As the population grows and pressure increases on natural resources', 'C:default/path/to/your/audio/file')
# (206, 'As trust properties have been either in lockdown or limiting visitors due to Covid since March 2020', 'C:default/path/to/your/audio/file')
# (207, 'As we improve our processes', 'C:default/path/to/your/audio/file')
# (208, 'Ashley Bloomfield', 'C:default/path/to/your/audio/file')
# (209, 'Aside from the constant fear about having an account shut', 'C:default/path/to/your/audio/file')
# (210, 'Ask any teacher and they will tell you the character of Jack in my book – a kid whos been abused and now acts abusively towards other kids – is not an unusual figure', 'C:default/path/to/your/audio/file')
# (211, 'Asked whether Australia intends to update its emissions reduction commitments as required by the Paris agreements five-yearly review process', 'C:default/path/to/your/audio/file')
# (212, 'At a certain point I was being transferred to cities I didnt even know existed', 'C:default/path/to/your/audio/file')
# (213, 'At first I thought Id be under protection for two or three days', 'C:default/path/to/your/audio/file')
# (214, 'At her lowest point', 'C:default/path/to/your/audio/file')
# (215, 'At its heart lies a tug of war between people who dont want politics intruding on a nice day out', 'C:default/path/to/your/audio/file')
# (216, 'At least seven people died in the disturbances', 'C:default/path/to/your/audio/file')
# (217, 'At one time he lived in New York', 'C:default/path/to/your/audio/file')
# (218, 'At that moment', 'C:default/path/to/your/audio/file')
# (219, 'At the same time', 'C:default/path/to/your/audio/file')
# (220, 'At this point', 'C:default/path/to/your/audio/file')
# (221, 'At trial', 'C:default/path/to/your/audio/file')
# (222, 'At war with the world', 'C:default/path/to/your/audio/file')
# (223, 'Atomos facility can produce about 1,000 servings of coffee a day', 'C:default/path/to/your/audio/file')
# (224, 'Australia has a moratorium on nuclear energy for one thing', 'C:default/path/to/your/audio/file')
# (225, 'Authorities may then face vaccine hesitant parents', 'C:default/path/to/your/audio/file')
# (226, 'Banking the proceeds of sex work is not a criminal offence', 'C:default/path/to/your/audio/file')
# (227, 'Banks are not on my side', 'C:default/path/to/your/audio/file')
# (228, 'Bauld believes current attitudes have been shaped by the Freedom Day narrative – the social contract made between the government and the public that if people came forward for vaccines', 'C:default/path/to/your/audio/file')
# (229, 'Before returning to his armoured vehicle', 'C:default/path/to/your/audio/file')
# (230, 'Beth Blandford', 'C:default/path/to/your/audio/file')
# (231, 'Bezos', 'C:default/path/to/your/audio/file')
# (232, 'Bezos actually knows what its like to ride on his own rocket', 'C:default/path/to/your/audio/file')
# (233, 'Bezos didnt even get the glory of being the first billionaire to ride his own rocket into space', 'C:default/path/to/your/audio/file')
# (234, 'Bezos dreams of moving heavy industry off of Earth and into space to reduce greenhouse gas emissions', 'C:default/path/to/your/audio/file')
# (235, 'Bezos founded Blue Origin with visionary goals', 'C:default/path/to/your/audio/file')
# (236, 'Bezos stepped down from his role as the CEO of Amazon and committed himself to spending more time focused on Blue Origin', 'C:default/path/to/your/audio/file')
# (237, 'Biden has always been a fierce defender of Hunter', 'C:default/path/to/your/audio/file')
# (238, 'Biden has called for urgent action on climate', 'C:default/path/to/your/audio/file')
# (239, 'Biden issued a memorandum establishing fighting corruption as a core national security interest', 'C:default/path/to/your/audio/file')
# (240, 'Birbalsingh is', 'C:default/path/to/your/audio/file')
# (241, 'Blue Origin became the first company to send a rocket above the Karman Line', 'C:default/path/to/your/audio/file')
# (242, 'Blue Origin employees continue to speak out', 'C:default/path/to/your/audio/file')
# (243, 'Blue Origin has all the ingredients for success and to become something truly fantastic', 'C:default/path/to/your/audio/file')
# (244, 'Blue Origin has struggled to hit its stride producing its powerful BE-4 rocket engine and as a result the maiden launch of ULAs Vulcan rocket has slipped to late 2022', 'C:default/path/to/your/audio/file')
# (245, 'Blue Origin should be one of the most successful space companies in the world', 'C:default/path/to/your/audio/file')
# (246, 'Blue Origins cultural problems started at the top and flowed down throughout the company', 'C:default/path/to/your/audio/file')
# (247, 'Blue Origins master plan has begun unraveling', 'C:default/path/to/your/audio/file')
# (248, 'Blue Origins troubles have both a technical and cultural dimension', 'C:default/path/to/your/audio/file')
# (249, 'Bluujaye Enriquez', 'C:default/path/to/your/audio/file')
# (250, 'Bluujaye took off without her phone or money', 'C:default/path/to/your/audio/file')
# (251, 'Bob Holsworth', 'C:default/path/to/your/audio/file')
# (252, 'Bob Smith', 'C:default/path/to/your/audio/file')
# (253, 'Bob Smith is one of the most incapable leaders I have ever encountered', 'C:default/path/to/your/audio/file')
# (254, 'Boris Johnson', 'C:default/path/to/your/audio/file')
# (255, 'Boris Johnson and Keir Starmer bent to lay wreaths and', 'C:default/path/to/your/audio/file')
# (256, 'Both', 'C:default/path/to/your/audio/file')
# (257, 'British diplomats say they are cautiously optimistic about overall progress', 'C:default/path/to/your/audio/file')
# (258, 'Built in 1820', 'C:default/path/to/your/audio/file')
# (259, 'Business accounts also add an extra level of security for sex workers who dont want to share their real name with clients', 'C:default/path/to/your/audio/file')
# (260, 'But', 'C:default/path/to/your/audio/file')
# (261, 'But Arthur Torrington', 'C:default/path/to/your/audio/file')
# (262, 'But Ben Eardley', 'C:default/path/to/your/audio/file')
# (263, 'But Biden himself has and will likely remain absent from Virginia', 'C:default/path/to/your/audio/file')
# (264, 'But Blue Origin was racked by more than just engineering difficulties', 'C:default/path/to/your/audio/file')
# (265, 'But Daniele Giovannucci', 'C:default/path/to/your/audio/file')
# (266, 'But Hackell said the CDC has reassured pediatricians that once authorization happens for 5- to-11-year-olds', 'C:default/path/to/your/audio/file')
# (267, 'But I also knew those stories had never received an anthropological interpretation', 'C:default/path/to/your/audio/file')
# (268, 'But I also worry what will happen to a province whose economy overwhelmingly depends on coal and heavy industries', 'C:default/path/to/your/audio/file')
# (269, 'But I never couldve imagined what would happen next', 'C:default/path/to/your/audio/file')
# (270, 'But I think reporters dont really understand sovereignty', 'C:default/path/to/your/audio/file')
# (271, 'But Liberals argue banks are acting prudently', 'C:default/path/to/your/audio/file')
# (272, 'But Natasha Mulvihill', 'C:default/path/to/your/audio/file')
# (273, 'But New Zealanders turned out in even greater numbers', 'C:default/path/to/your/audio/file')
# (274, 'But Purdey is a rewilding enthusiast', 'C:default/path/to/your/audio/file')
# (275, 'But Trump countered that political wisdom with some of his own: The only guys that win are the guys that embrace the Maga movement', 'C:default/path/to/your/audio/file')
# (276, 'But a few years ago', 'C:default/path/to/your/audio/file')
# (277, 'But although he survived an assassination plot', 'C:default/path/to/your/audio/file')
# (278, 'But as the night went on', 'C:default/path/to/your/audio/file')
# (279, 'But at least two dozen problematic hashtags have managed to slip through the cracks', 'C:default/path/to/your/audio/file')
# (280, 'But being confronted with history you didnt learn at school can', 'C:default/path/to/your/audio/file')
# (281, 'But by 2015', 'C:default/path/to/your/audio/file')
# (282, 'But even if these efforts were eventually successful', 'C:default/path/to/your/audio/file')
# (283, 'But feeling like she doesnt have any help from law enforcement or the media has made it much worse', 'C:default/path/to/your/audio/file')
# (284, 'But finding a bank willing to take the money is a little more complicated', 'C:default/path/to/your/audio/file')
# (285, 'But former Cabinet minister David Davis disagreed: Sure', 'C:default/path/to/your/audio/file')
# (286, 'But he steered clear of an event hosted by Trump strategist Steve Bannon who may face contempt charges on Tuesday for refusing to cooperate with an investigation into the 6 January Capitol riot', 'C:default/path/to/your/audio/file')
# (287, 'But hes also not the upstanding citizen that the White House wants you to believe', 'C:default/path/to/your/audio/file')
# (288, 'But his latest pursuit', 'C:default/path/to/your/audio/file')
# (289, 'But if the president is forced to abandon the clean energy provision', 'C:default/path/to/your/audio/file')
# (290, 'But if you measure our success by recommendations actually enacted by government', 'C:default/path/to/your/audio/file')
# (291, 'But in the end', 'C:default/path/to/your/audio/file')
# (292, 'But it also built houses and pubs', 'C:default/path/to/your/audio/file')
# (293, 'But it changes peoples belief about what others think', 'C:default/path/to/your/audio/file')
# (294, 'But it has gone into the background', 'C:default/path/to/your/audio/file')
# (295, 'But it still could be a disappointment when the Biden administration doesnt live up to what it might do in terms of transparency', 'C:default/path/to/your/audio/file')
# (296, 'But it was the inclusion of Churchills home at Chartwell', 'C:default/path/to/your/audio/file')
# (297, 'But it wasnt until she moved to Wales recently', 'C:default/path/to/your/audio/file')
# (298, 'But its unclear how many people would be willing to give up conventional coffee for one of its beanless counterparts', 'C:default/path/to/your/audio/file')
# (299, 'But just a few days later', 'C:default/path/to/your/audio/file')
# (300, 'But just because our education system didnt really prepare us for this', 'C:default/path/to/your/audio/file')
# (301, 'But my attitude', 'C:default/path/to/your/audio/file')
# (302, 'But only', 'C:default/path/to/your/audio/file')
# (303, 'But other Democratic heavy-weights are traveling to Virginia to soothe Democratic anxiety and try to propel McAuliffes campaign toward the decisive victory they need', 'C:default/path/to/your/audio/file')
# (304, 'But other details from the court documents relating to Rumayyans role in PIFs acquisition of the charter jet firm and other companies have not previously been reported', 'C:default/path/to/your/audio/file')
# (305, 'But others promoted sterilization', 'C:default/path/to/your/audio/file')
# (306, 'But perhaps a change is imminent', 'C:default/path/to/your/audio/file')
# (307, 'But relations with donor families remain a delicate subject', 'C:default/path/to/your/audio/file')
# (308, 'But she doesnt regret the work itself', 'C:default/path/to/your/audio/file')
# (309, 'But she estimates every castle volunteer has fielded at least one angry outburst', 'C:default/path/to/your/audio/file')
# (310, 'But she worries about the chilling effect on other charities and cultural institutions', 'C:default/path/to/your/audio/file')
# (311, 'But shes determined to prove the changes can be economically viable', 'C:default/path/to/your/audio/file')
# (312, 'But since September China has been experiencing its own coal dilemma', 'C:default/path/to/your/audio/file')
# (313, 'But so', 'C:default/path/to/your/audio/file')
# (314, 'But some kids are at risk for severe illness', 'C:default/path/to/your/audio/file')
# (315, 'But something is amiss', 'C:default/path/to/your/audio/file')
# (316, 'But such issues are not limited to the Facebook-owned social media company', 'C:default/path/to/your/audio/file')
# (317, 'But that proves a red line for Liberals in metropolitan seats', 'C:default/path/to/your/audio/file')
# (318, 'But the Hindus of Bangladesh will never forget Durga Puja in 2021', 'C:default/path/to/your/audio/file')
# (319, 'But the Nationals want to prolong coal generation', 'C:default/path/to/your/audio/file')
# (320, 'But the Premier League approved the deal this month and said it had been given legally binding assurances that the Kingdom of Saudi Arabia will not control the club', 'C:default/path/to/your/audio/file')
# (321, 'But the flowers arrived unexpectedly this summer via a young black academic named April-Louise Pennant', 'C:default/path/to/your/audio/file')
# (322, 'But the latest news from the US and China', 'C:default/path/to/your/audio/file')
# (323, 'But the row hasnt gone away', 'C:default/path/to/your/audio/file')
# (324, 'But the work paid off', 'C:default/path/to/your/audio/file')
# (325, 'But then', 'C:default/path/to/your/audio/file')
# (326, 'But there is no mechanism to monitor the agreement', 'C:default/path/to/your/audio/file')
# (327, 'But there probably will not be the kind of heavy demand seen when shots first became available for adults', 'C:default/path/to/your/audio/file')
# (328, 'But this feels uglier', 'C:default/path/to/your/audio/file')
# (329, 'But this thing with my daughter gone has brought me to my knees.', 'C:default/path/to/your/audio/file')
# (330, 'But understandable huge anxiety among MPs now', 'C:default/path/to/your/audio/file')
# (331, 'But we can hardly wait to see what … images will reveal about these fossils from the formation of the solar system.', 'C:default/path/to/your/audio/file')
# (332, 'But what really bothers me is seeing my family have to move from town to town', 'C:default/path/to/your/audio/file')
# (333, 'But when she returned to her normal life', 'C:default/path/to/your/audio/file')
# (334, 'But why should the trust be a target? I think its one of the steadying reminders of whats good about life – people like the consistency', 'C:default/path/to/your/audio/file')
# (335, 'Butcher Lee Jordo', 'C:default/path/to/your/audio/file')
# (336, 'Buttigieg added', 'C:default/path/to/your/audio/file')
# (337, 'Buttigieg said about Carlson on MSNBC', 'C:default/path/to/your/audio/file')
# (338, 'Buttigieg – who is gay – was the subject of criticism from Fox News host Tucker Carlson on Thursday', 'C:default/path/to/your/audio/file')
# (339, 'By 2017-18', 'C:default/path/to/your/audio/file')
# (340, 'By all measures', 'C:default/path/to/your/audio/file')
# (341, 'By making sex workers poorer with less access to resources such as banking services and business platforms', 'C:default/path/to/your/audio/file')
# (342, 'By the 1960s', 'C:default/path/to/your/audio/file')
# (343, 'By the next day it had morphed into fear', 'C:default/path/to/your/audio/file')
# (344, 'By virtue of the fact thats it going to go on and on … the public may start saying: ‘We cant keep having 1,000 deaths a week', 'C:default/path/to/your/audio/file')
# (345, 'CDC guidance said immunization program managers can start ordering doses Wednesday', 'C:default/path/to/your/audio/file')
# (346, 'California', 'C:default/path/to/your/audio/file')
# (347, 'Calling many of your own constituents ‘filth means you have no intention of representing them', 'C:default/path/to/your/audio/file')
# (348, 'Carlson is one of the most controversial figures in US media with a history of extremist and racist statements that have often angered advertisers but have won him a hardcore fanbase that makes his show consistently one of the most popular on cable news.', 'C:default/path/to/your/audio/file')
# (349, 'Celia Richardson', 'C:default/path/to/your/audio/file')
# (350, 'Chands son', 'C:default/path/to/your/audio/file')
# (351, 'Charging Crow went to her friends apartment', 'C:default/path/to/your/audio/file')
# (352, 'China', 'C:default/path/to/your/audio/file')
# (353, 'Chinas coal capital', 'C:default/path/to/your/audio/file')
# (354, 'Chinas energy structure is dominated by coal power', 'C:default/path/to/your/audio/file')
# (355, 'Chinas most powerful leader in many years', 'C:default/path/to/your/audio/file')
# (356, 'Chinas reliance on dirty coal is a vicious circle that the province of 37 million people can not easily pull itself out of', 'C:default/path/to/your/audio/file')
# (357, 'Claiming self-defense', 'C:default/path/to/your/audio/file')
# (358, 'Claims that the trust was haemorrhaging members and purging dissenting staff followed', 'C:default/path/to/your/audio/file')
# (359, 'Clark added', 'C:default/path/to/your/audio/file')
# (360, 'Clarke Gayford', 'C:default/path/to/your/audio/file')
# (361, 'Coal is the main source of power generation in China', 'C:default/path/to/your/audio/file')
# (362, 'Colfer explained that there are actually many more missing Indigenous people that are not reflected in official numbers', 'C:default/path/to/your/audio/file')
# (363, 'Colombian government has so far sterilized 24 using a chemical that makes them infertile', 'C:default/path/to/your/audio/file')
# (364, 'Commons time will be set aside for tributes to Amess and the former Home Office minister James Brokenshire', 'C:default/path/to/your/audio/file')
# (365, 'Comparatively', 'C:default/path/to/your/audio/file')
# (366, 'Compound Foods', 'C:default/path/to/your/audio/file')
# (367, 'Computer-typed and delivered by hand in the early morning', 'C:default/path/to/your/audio/file')
# (368, 'Confidential documents leaked to the Observer reveal an extraordinary rift between Boris Johnson and his chancellor', 'C:default/path/to/your/audio/file')
# (369, 'Consistency is so last decade', 'C:default/path/to/your/audio/file')
# (370, 'Cook said', 'C:default/path/to/your/audio/file')
# (371, 'Cop26', 'C:default/path/to/your/audio/file')
# (372, 'Corinne Fowler', 'C:default/path/to/your/audio/file')
# (373, 'Counter-terrorism detectives from the Mets SO15 unit', 'C:default/path/to/your/audio/file')
# (374, 'Coupled with a decrease in coal consumption', 'C:default/path/to/your/audio/file')
# (375, 'Critics say Hunters presence at the recent gallery event in Hollywood undercut claims that neither he nor the White House would know the identity of buyers', 'C:default/path/to/your/audio/file')
# (376, 'Darlington Memorial Hospital reportedly had queues of up to 15 ambulances this month with crews waiting hours to transfer patients', 'C:default/path/to/your/audio/file')
# (377, 'Data published by the coronavirus taskforce on Saturday shows that an estimated 45% of the countrys population may have an immunity to Covid-19 after receiving a vaccine or recovering from the illness', 'C:default/path/to/your/audio/file')
# (378, 'David Peter Young', 'C:default/path/to/your/audio/file')
# (379, 'David Rubenstein', 'C:default/path/to/your/audio/file')
# (380, 'Dawnay argues: Im sure in 1895 there must have been a lot of people thinking it was outrageous', 'C:default/path/to/your/audio/file')
# (381, 'Dawnay says', 'C:default/path/to/your/audio/file')
# (382, 'DeGuerin confirmed to the Times that Durst had been hospitalized and placed on a ventilator in a wing of USC medical center under the watch of the Los Angeles county sheriffs department where he has been through out his recent murder trial', 'C:default/path/to/your/audio/file')
# (383, 'Deadly communal violence has broken out in Bangladesh after allegations of the desecration of an Islamic holy book led to dozens of Hindu temples being attacked and police opening fire on a crowd', 'C:default/path/to/your/audio/file')
# (384, 'Death would be more acceptable than this constant pressure', 'C:default/path/to/your/audio/file')
# (385, 'Deb Haaland', 'C:default/path/to/your/audio/file')
# (386, 'Democratic candidate Terry McAuliffe said', 'C:default/path/to/your/audio/file')
# (387, 'Democratic lawmakers and numerous rights groups have criticized Robinson', 'C:default/path/to/your/audio/file')
# (388, 'Democrats have got to quit talking', 'C:default/path/to/your/audio/file')
# (389, 'Departures from the policy are assessed on a case-by-case basis and can be approved when the bank is comfortable that such a departure would not pose harm to a prospective customer', 'C:default/path/to/your/audio/file')
# (390, 'Despite their orbits', 'C:default/path/to/your/audio/file')
# (391, 'Details of Rumayyans role – including the transfer of a charter jet company to the Public Investment Fund (PIF)', 'C:default/path/to/your/audio/file')
# (392, 'Detectives from the specialist crime command are investigating.', 'C:default/path/to/your/audio/file')
# (393, 'Detectives were on Saturday granted a warrant to hold him until 22 October', 'C:default/path/to/your/audio/file')
# (394, 'Dhaka', 'C:default/path/to/your/audio/file')
# (395, 'Disagreements with politicians should be solved at the ballot box not via threats', 'C:default/path/to/your/audio/file')
# (396, 'Disney and Citibank', 'C:default/path/to/your/audio/file')
# (397, 'Do not be afraid', 'C:default/path/to/your/audio/file')
# (398, 'Do not be scared', 'C:default/path/to/your/audio/file')
# (399, 'Doctors are warning that accident and emergency departments are on the edge of a precipice', 'C:default/path/to/your/audio/file')
# (400, 'Does McGrady sense a change in the political weather? Id certainly like to think the nations being a bit kinder to itself', 'C:default/path/to/your/audio/file')
# (401, 'Donald Johanson', 'C:default/path/to/your/audio/file')
# (402, 'Donald Trumps attempts to weaponise Hunters problems for political gain in the 2020 presidential election fell flat', 'C:default/path/to/your/audio/file')
# (403, 'Dont do it', 'C:default/path/to/your/audio/file')
# (404, 'Dorothy Ciner', 'C:default/path/to/your/audio/file')
# (405, 'Dorset and Wiltshire fire and rescue service said it arrived at the scene at 11.57am on Friday with two fire engines and a heavy rescue unit', 'C:default/path/to/your/audio/file')
# (406, 'Dozens of people have reported testing negative using a Covid PCR test', 'C:default/path/to/your/audio/file')
# (407, 'Dozens were injured', 'C:default/path/to/your/audio/file')
# (408, 'Dr Aseem Malhotra', 'C:default/path/to/your/audio/file')
# (409, 'Dr Ian Higginson', 'C:default/path/to/your/audio/file')
# (410, 'Dr Jesse Hackell registered early with New York state to be able to administer the shots to teens', 'C:default/path/to/your/audio/file')
# (411, 'Dr Patty Loew', 'C:default/path/to/your/audio/file')
# (412, 'Dr Richard Besser called on the government to do more to address racial and economic disparities that might emerge in the push to vaccinate younger kids.For example', 'C:default/path/to/your/audio/file')
# (413, 'Drawing power from two huge circular solar wings', 'C:default/path/to/your/audio/file')
# (414, 'During Wrights three years', 'C:default/path/to/your/audio/file')
# (415, 'During lockdown', 'C:default/path/to/your/audio/file')
# (416, 'During the pandemic', 'C:default/path/to/your/audio/file')
# (417, 'Durst appeared frail and at times confused at trial', 'C:default/path/to/your/audio/file')
# (418, 'Durst had fled to Texas after Bermans killing and lived under an assumed name', 'C:default/path/to/your/audio/file')
# (419, 'Durst was acquitted of Blacks murder in 2001', 'C:default/path/to/your/audio/file')
# (420, 'Dursts attorney Dick DeGuerin told the newspaper his client was in very bad condition during the sentencing hearing and was having difficulty breathing and he was having difficulty communicating', 'C:default/path/to/your/audio/file')
# (421, 'ECA has advised him of the matter', 'C:default/path/to/your/audio/file')
# (422, 'Eardley says', 'C:default/path/to/your/audio/file')
# (423, 'Earlier', 'C:default/path/to/your/audio/file')
# (424, 'Earlier in the week', 'C:default/path/to/your/audio/file')
# (425, 'Earlier this week', 'C:default/path/to/your/audio/file')
# (426, 'Earlier this year', 'C:default/path/to/your/audio/file')
# (427, 'Earlier this year Hunter published a memoir in which he detailed his struggle with alcoholism and drug abuse and denied wrongdoing in joining the board of Burisma', 'C:default/path/to/your/audio/file')
# (428, 'Ebrahim Raisi', 'C:default/path/to/your/audio/file')
# (429, 'Ed Matthew', 'C:default/path/to/your/audio/file')
# (430, 'Efforts by the Guardian to engage with diet content led to full-blown eating disorder promotion in less than 24 hours', 'C:default/path/to/your/audio/file')
# (431, 'Eleanor Hardings attempt to foreground a history unusually well preserved in the family archive that Richard Pennants descendants gave to Bangor University in the 1930s', 'C:default/path/to/your/audio/file')
# (432, 'Eleven students drowned and 10 others were rescued during a school outing for a river cleanup in Indonesias West Java province', 'C:default/path/to/your/audio/file')
# (433, 'Ellwood', 'C:default/path/to/your/audio/file')
# (434, 'Emissions reductions by different means have no greater or lesser moral qualities', 'C:default/path/to/your/audio/file')
# (435, 'Ending a dependency on coal at home has proved trickier', 'C:default/path/to/your/audio/file')
# ...
# (3504, 'which was so popular that membership soared from about 50,000 in 1960 to a million by 1981', 'C:default/path/to/your/audio/file')
# (3505, 'which was the same as taking Gods name in vain', 'C:default/path/to/your/audio/file')
# (3506, 'which were originally introduced to Escobars Hacienda Napoles estate', 'C:default/path/to/your/audio/file')
# (3507, 'which were then open to all comers', 'C:default/path/to/your/audio/file')
# (3508, 'which will contain policies on cutting emissions and creating green jobs', 'C:default/path/to/your/audio/file')
# (3509, 'which will meet on Monday to discuss the implications of Amesss killing', 'C:default/path/to/your/audio/file')
# (3510, 'while 999 took nearly one million calls last month', 'C:default/path/to/your/audio/file')
# (3511, 'while Alan M compares the narrow (and oh so fashionable) angle taken to present a complex subject to communist rewritings of history', 'C:default/path/to/your/audio/file')
# (3512, 'while Hancock was health secretary', 'C:default/path/to/your/audio/file')
# (3513, 'while House speaker Nancy Pelosi plans a fundraiser', 'C:default/path/to/your/audio/file')
# (3514, 'while Rudyard Kiplings former Sussex home earned its entry for his writings on empire', 'C:default/path/to/your/audio/file')
# (3515, 'while another remains on guard at the entrance', 'C:default/path/to/your/audio/file')
# (3516, 'while highlighting a bleak future', 'C:default/path/to/your/audio/file')
# (3517, 'while industry body UK Finance does not provide any guidance for its members on the issue', 'C:default/path/to/your/audio/file')
# (3518, 'while not illegal', 'C:default/path/to/your/audio/file')
# (3519, 'while others are accepting of the current situation', 'C:default/path/to/your/audio/file')
# (3520, 'while others trail it', 'C:default/path/to/your/audio/file')
# (3521, 'while reducing carbon emissions and building resilience to extreme weather', 'C:default/path/to/your/audio/file')
# (3522, 'while small donations trebled', 'C:default/path/to/your/audio/file')
# (3523, 'while the costs of inaction are large and rising', 'C:default/path/to/your/audio/file')
# (3524, 'while the gift shop is a soothing vision of gardening tools', 'C:default/path/to/your/audio/file')
# (3525, 'while the other agents remain outside to guard the door', 'C:default/path/to/your/audio/file')
# (3526, 'while the other is a poet living between the UK and Cyprus – have donated to charities in Jamaica', 'C:default/path/to/your/audio/file')
# (3527, 'while the world is moving to medium-term targets for 2030', 'C:default/path/to/your/audio/file')
# (3528, 'while vaccination has changed the outcome of high Covid rates', 'C:default/path/to/your/audio/file')
# (3529, 'white users', 'C:default/path/to/your/audio/file')
# (3530, 'who adopted newborn twins with his husband Chasten', 'C:default/path/to/your/audio/file')
# (3531, 'who advised the World Bank on the report', 'C:default/path/to/your/audio/file')
# (3532, 'who also attended', 'C:default/path/to/your/audio/file')
# (3533, 'who are coming to Penrhyn', 'C:default/path/to/your/audio/file')
# (3534, 'who belittled the secretarys paternity leave while making homophobic comments and criticizing the administration for supply chain woes', 'C:default/path/to/your/audio/file')
# (3535, 'who chairs the Commons defence committee', 'C:default/path/to/your/audio/file')
# (3536, 'who co-authored it with the trusts head curator', 'C:default/path/to/your/audio/file')
# (3537, 'who died this month from cancer', 'C:default/path/to/your/audio/file')
# (3538, 'who grew up on an organic farm on Exmoor', 'C:default/path/to/your/audio/file')
# (3539, 'who has also been linked to the death of neighbor Morris Black', 'C:default/path/to/your/audio/file')
# (3540, 'who has been dogged by controversies for years and whose tax affairs are currently under investigation by the justice department', 'C:default/path/to/your/audio/file')
# (3541, 'who has been on paternity leave since mid-August with newborn twins', 'C:default/path/to/your/audio/file')
# (3542, 'who has been rescuing snakes for 32 years and has been bitten 13 times', 'C:default/path/to/your/audio/file')
# (3543, 'who has his own endorsement issues to deal with', 'C:default/path/to/your/audio/file')
# (3544, 'who has lived in Belfairs for more than 50 years', 'C:default/path/to/your/audio/file')
# (3545, 'who has lived in the area for a decade', 'C:default/path/to/your/audio/file')
# (3546, 'who has lived in the area for more than 20 years', 'C:default/path/to/your/audio/file')
# (3547, 'who has said he strongly opposes the clean energy deal', 'C:default/path/to/your/audio/file')
# (3548, 'who has seen his popularity fall in the aftermath of the botched Afghanistan withdrawal and legislative gridlock on the main plans of his domestic agenda and growing uncertainty of post-pandemic economic recovery', 'C:default/path/to/your/audio/file')
# (3549, 'who has since doubled down on his comments', 'C:default/path/to/your/audio/file')
# (3550, 'who have been claiming for many years', 'C:default/path/to/your/audio/file')
# (3551, 'who have higher rates of death and hospitalization than children', 'C:default/path/to/your/audio/file')
# (3552, 'who in return break it down', 'C:default/path/to/your/audio/file')
# (3553, 'who is Tlingit and the National Indigenous Womens Resource Centers senior native affairs adviser', 'C:default/path/to/your/audio/file')
# (3554, 'who is a former Cabinet minister', 'C:default/path/to/your/audio/file')
# (3555, 'who is a member of the Bad River Band of Lake Superior Ojibwe', 'C:default/path/to/your/audio/file')
# (3556, 'who is a member of the Commons Commission', 'C:default/path/to/your/audio/file')
# (3557, 'who is believed to have been referred to the Prevent programme but is not on MI5s database of persons of interest', 'C:default/path/to/your/audio/file')
# (3558, 'who is biracial', 'C:default/path/to/your/audio/file')
# (3559, 'who is endorsed by Restore Trust', 'C:default/path/to/your/audio/file')
# (3560, 'who is from Costa Rica', 'C:default/path/to/your/audio/file')
# (3561, 'who is in charge of Lucys black-and-white camera', 'C:default/path/to/your/audio/file')
# (3562, 'who is now 42', 'C:default/path/to/your/audio/file')
# (3563, 'who is worth just south of $200bn', 'C:default/path/to/your/audio/file')
# (3564, 'who last week launched a graphic novel about his life illustrated by Israeli comic book artist Asaf Hanuka', 'C:default/path/to/your/audio/file')
# (3565, 'who led a parliamentary debate on the trust last autumn', 'C:default/path/to/your/audio/file')
# (3566, 'who lives in Madrid', 'C:default/path/to/your/audio/file')
# (3567, 'who lost Virginia by 10% in 2020', 'C:default/path/to/your/audio/file')
# (3568, 'who made a plan to assassinate the writer in an attack on Christmas day', 'C:default/path/to/your/audio/file')
# (3569, 'who now works as a climate campaigner', 'C:default/path/to/your/audio/file')
# (3570, 'who ran a Belfairs GP surgery before succumbing to Covid-19 last year', 'C:default/path/to/your/audio/file')
# (3571, 'who rejected the international scientific consensus on a world heating up', 'C:default/path/to/your/audio/file')
# (3572, 'who remained at the scene and was present when officers arrived', 'C:default/path/to/your/audio/file')
# (3573, 'who reveals how he decided to hold his own two-hour surgery just four hours after learning of Amesss killing', 'C:default/path/to/your/audio/file')
# (3574, 'who suspects most trust members arent enormously interested in the row', 'C:default/path/to/your/audio/file')
# (3575, 'who threw stones and smashed statues of the Hindu gods', 'C:default/path/to/your/audio/file')
# (3576, 'who travelled to Cape Canaveral in Florida for the launch', 'C:default/path/to/your/audio/file')
# (3577, 'who tweeted this summer appealing for critics to stop treating it like a political football', 'C:default/path/to/your/audio/file')
# (3578, 'who was director of the Office of Government Ethics under President Barack Obama', 'C:default/path/to/your/audio/file')
# (3579, 'who was forced into hiding after receiving death threats over his novel The Satanic Verses', 'C:default/path/to/your/audio/file')
# (3580, 'who was killed by police in 1993', 'C:default/path/to/your/audio/file')
# (3581, 'who was ousted by the army in April 2019 following weeks of mass protests', 'C:default/path/to/your/audio/file')
# (3582, 'who was tapped by Bezos to lead the company in 2017', 'C:default/path/to/your/audio/file')
# (3583, 'who were abused and neglected as children', 'C:default/path/to/your/audio/file')
# (3584, 'who were sent to a nearby hospital', 'C:default/path/to/your/audio/file')
# (3585, 'who worked for Cooper from 2013 to 2019', 'C:default/path/to/your/audio/file')
# (3586, 'who works at Southmoor academy in Sunderland', 'C:default/path/to/your/audio/file')
# (3587, 'who works in the bustling parade of shops 100 metres from the scene', 'C:default/path/to/your/audio/file')
# (3588, 'whose body has never been found', 'C:default/path/to/your/audio/file')
# (3589, 'whose body parts were found In Galveston Bay', 'C:default/path/to/your/audio/file')
# (3590, 'whose body was discovered late last month in a national park in Wyoming after a rapid-fire law enforcement response and national news media frenzy', 'C:default/path/to/your/audio/file')
# (3591, 'whose first', 'C:default/path/to/your/audio/file')
# (3592, 'whose handwritten card dedicates them to the enslaved people whose blood and sweat and tears contributed to the wealth that built this castle', 'C:default/path/to/your/audio/file')
# (3593, 'whose manner is as calm and soothing as a stroll round a herbaceous border', 'C:default/path/to/your/audio/file')
# (3594, 'whose membership includes leaders and influential voices in the Windrush community', 'C:default/path/to/your/audio/file')
# (3595, 'whose number has more than doubled since 2012', 'C:default/path/to/your/audio/file')
# (3596, 'whose popularity among independents and left-wing Democrats is far from assured', 'C:default/path/to/your/audio/file')
# (3597, 'will no longer become a special envoy for the United Nations', 'C:default/path/to/your/audio/file')
# (3598, 'will not attend the Cop26 gathering', 'C:default/path/to/your/audio/file')
# (3599, 'will pay a heavy price for what they have done', 'C:default/path/to/your/audio/file')
# (3600, 'will quickly call 999 for backup.', 'C:default/path/to/your/audio/file')
# (3601, 'will raise questions about how much progress the meeting can make towards core emissions goals', 'C:default/path/to/your/audio/file')
# (3602, 'will showcase three figures – a man', 'C:default/path/to/your/audio/file')
# (3603, 'with 51 million having received one shot', 'C:default/path/to/your/audio/file')
# (3604, 'with Boris Johnson and Sir Keir Starmer', 'C:default/path/to/your/audio/file')
# (3605, 'with a deal on providing $100bn to developing countries expected to be sealed and some advances on an agreement to halt deforestation and the destruction of nature', 'C:default/path/to/your/audio/file')
# (3606, 'with a population of 20,000', 'C:default/path/to/your/audio/file')
# (3607, 'with a rate of deaths per million people nearly triple those seen in France', 'C:default/path/to/your/audio/file')
# (3608, 'with a total of 7,958,384 cases', 'C:default/path/to/your/audio/file')
# (3609, 'with a young family to support and lacking the skills to switch career', 'C:default/path/to/your/audio/file')
# (3610, 'with about 150 Hindus injured and two killed', 'C:default/path/to/your/audio/file')
# (3611, 'with an aim of having no cases', 'C:default/path/to/your/audio/file')
# (3612, 'with complaints that the trust was becoming a cosy club for the gentry', 'C:default/path/to/your/audio/file')
# (3613, 'with delays in discharging patients', 'C:default/path/to/your/audio/file')
# (3614, 'with just weeks to go before the crucial Cop26 climate summit', 'C:default/path/to/your/audio/file')
# (3615, 'with many Russians citing distrust of the authorities and fear of new medical products', 'C:default/path/to/your/audio/file')
# (3616, 'with more than 2.5% of the population responding to the call to get jabbed on a single day', 'C:default/path/to/your/audio/file')
# (3617, 'with no one escorting me', 'C:default/path/to/your/audio/file')
# (3618, 'with one-fifth of ICU beds occupied by Covid patients', 'C:default/path/to/your/audio/file')
# (3619, 'with patients forced to wait in ambulances for up to 11 hours outside hospitals', 'C:default/path/to/your/audio/file')
# (3620, 'with power shortages spread across key regions', 'C:default/path/to/your/audio/file')
# (3621, 'with six in intensive care.', 'C:default/path/to/your/audio/file')
# (3622, 'with some demanding his resignation while others request to meet him to discuss his remarks', 'C:default/path/to/your/audio/file')
# (3623, 'with stability', 'C:default/path/to/your/audio/file')
# (3624, 'with the RET due to expire in 2020', 'C:default/path/to/your/audio/file')
# (3625, 'with the Sacramento police department', 'C:default/path/to/your/audio/file')
# (3626, 'with the caption: A stroll through a well-appointed garden is where you can find your calm', 'C:default/path/to/your/audio/file')
# (3627, 'with the sole purpose of tightening its grip on power', 'C:default/path/to/your/audio/file')
# (3628, 'woman and child – dressed in their Sunday best climbing a mountain of suitcases hand-in-hand', 'C:default/path/to/your/audio/file')
# (3629, 'wood and metal with oil', 'C:default/path/to/your/audio/file')
# (3630, 'work', 'C:default/path/to/your/audio/file')
# (3631, 'working to try to save nature – this is really important right now', 'C:default/path/to/your/audio/file')
# (3632, 'working with two like-minded colleagues', 'C:default/path/to/your/audio/file')
# (3633, 'would be permanently inundated', 'C:default/path/to/your/audio/file')
# (3634, 'would face frequent flooding', 'C:default/path/to/your/audio/file')
# (3635, 'would it make life easier if I was to go? Yet she has', 'C:default/path/to/your/audio/file')
# (3636, 'would set the prices of the art and not reveal who bid on or bought it', 'C:default/path/to/your/audio/file')
# (3637, 'yet the national mood seems sanguine', 'C:default/path/to/your/audio/file')
# (3638, 'you can get in touch by filling in the form below or contact us via WhatsApp by clicking here or adding +44(0)7766780300', 'C:default/path/to/your/audio/file')
# (3639, 'you can see right across the valley – a lush patchwork of forest', 'C:default/path/to/your/audio/file')
# (3640, 'you get up and you keep going', 'C:default/path/to/your/audio/file')
# (3641, 'you know', 'C:default/path/to/your/audio/file')
# (3642, 'you know you just keep going', 'C:default/path/to/your/audio/file')
# (3643, 'you run into spider webs and dirt and it smells crappy and its musty and youre on your belly and youre dirty', 'C:default/path/to/your/audio/file')
# (3644, 'youre less likely to act on it', 'C:default/path/to/your/audio/file')
# (3645, 'yupo paper', 'C:default/path/to/your/audio/file')
# (3646, '‘I love this place', 'C:default/path/to/your/audio/file')
# (3647, '‘Im better than the absolute worst that prior to 2016 you couldnt have even conceived of', 'C:default/path/to/your/audio/file')
# (3648, '‘Im going to resign now – they wont visit', 'C:default/path/to/your/audio/file')
# (3649, '‘Mom', 'C:default/path/to/your/audio/file')
# (3650, '‘Oh', 'C:default/path/to/your/audio/file')
# (3651, '‘Theres got to be a better way to do this', 'C:default/path/to/your/audio/file')
# (3652, '‘Turn up at this prison on this day', 'C:default/path/to/your/audio/file')
# (3653, '‘Well', 'C:default/path/to/your/audio/file')
# (3654, '‘Why am I putting myself through this? Would it be better for the trust', 'C:default/path/to/your/audio/file')
# (3655, '‘You need surnames and the slaves were either given or picked the surnames of the people they worked for? Of course', 'C:default/path/to/your/audio/file')
# (3656, '‘oh another kid; ‘oh theres so many', 'C:default/path/to/your/audio/file')
# (3657, '‘‘Many people have forgotten how this story began and why I am under escort today', 'C:default/path/to/your/audio/file')

# %%
from tqdm import tqdm

# %% [markdown]
# # Insert data into DB

# %%
# Do the insert
for content in tqdm(final_content):
        cursor.execute("insert into ATData(TEXT) values (?)", str(content))
        conn.commit()
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 3656/3656 [00:02<00:00, 1256.91it/s]

# %%
import pyodbc 

# SELECT @@SERVERNAME
# Use this to find servername

conn = pyodbc.connect('Driver={SQL Server};'
                          'Server=LAPTOP-Q0DB1ITI\SQLEXPRESS;'
                      'Database=DB;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute("""SELECT TOP(1) FROM user""")
for i in cursor:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-19-ef18452a8aaa> in <module>
#      10
#      11 cursor = conn.cursor()
# ---> 12 cursor.execute("""SELECT TOP(1) FROM user""")
#      13 for i in cursor:
#      14     print(i)
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]接近關鍵字 'FROM' 之處的語法不正確。 (156) (SQLExecDirectW)")
